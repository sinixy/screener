# %%
import yfinance
import pandas as pd

from stocks import get_stocks

# %%
stocks = get_stocks()
stocks
# Out:
#      symbol                                               name   lastsale
# 0      MSFT                 Microsoft Corporation Common Stock   430.1600  \
# 1      AAPL                            Apple Inc. Common Stock   189.9800
# 2      NVDA                    NVIDIA Corporation Common Stock  1064.6900
# 3      GOOG                Alphabet Inc. Class C Capital Stock   176.3300
# 4     GOOGL                 Alphabet Inc. Class A Common Stock   174.9900
# ...     ...                                                ...        ...
# 4455  UKOMW  Ucommune International Ltd Warrant expiring 11...     0.0083
# 4456   QVCC     QVC, Inc. 6.250% Senior Secured Notes due 2068    12.6900
# 4457   QVCD     QVC, Inc. 6.375% Senior Secured Notes due 2067    12.7208
# 4458   CTBB              Qwest Corporation 6.5% Notes due 2056     9.8000
# 4459   CTDD             Qwest Corporation 6.75% Notes due 2057     9.9100
#
#           marketCap
# 0     3197080660347
# 1     2913168898360
# ...

# %%
tickers = yfinance.Tickers(stocks.symbol.to_list())
tickers
# Out:
# yfinance.Tickers object <MSFT,AAPL,NVDA,GOOG,GOOGL,AMZN,META,BRK-A,BRK-B,LLY,AVGO,JPM,TSLA,WMT,V,UNH,XOM,MA,PG,COST,JNJ,ORCL,MRK,HD,BAC,CVX,NFLX,ABBV,AMD,KO,CRM,PEP,QCOM,TMO,CCZ,ADBE,WFC,LIN,DHR,TMUS,CSCO,MCD,DIS,AMAT,GE,TXN,ABT,AXP,TBC,CAT,INTU,AMGN,PFE,TBB,MS,NEE,IBM,PM,NOW,CMCSA,GS,ISRG,MU,UNP,RTX,NKE,COP,SPGI,UBER,SCHW,INTC,HON,BKNG,SYK,LRCX,T,LOW,C,ELV,PGR,UPS,VRTX,BLK,TJX,ADI,DELL,LMT,BSX,MDT,REGN,BA,KLAC,DE,PANW,MMC,ADP,PLD,ANET,CI,KKR,ABNB,MDLZ,SCCO,SNPS,SBUX,BX,FI,AMT,CMG,SO,CRWD,WM,BMY,HCA,TRI,GD,GILD,APH,CDNS,DUK,ICE,MO,ZTS,CME,SHW,CL,TDG,MCO,FCX,MCK,EQIX,CEG,ITW,EOG,CVS,CTAS,NOC,PH,MAR,TGT,ECL,MRVL,BDX,CSX,APO,EMR,PYPL,MRNA,USB,MPC,PNC,EPD,AON,FDX,MSI,PSX,WELL,CARR,RSG,APD,COIN,WDAY,ROP,ORLY,PCAR,MMM,AJG,OXY,MNST,PCG,VLO,MCHP,EW,COF,PFH,SNOW,ET,CPRT,AIG,SMCI,MET,TFC,NSC,HLT,DXCM,GM,AFL,WMB,TRV,GEV,F,NEM,AZO,SPG,SRE,PSA,ROST,DHI,GWW,OKE,AEP,FTNT,PLTR,HES,KDP,TTD,DASH,ADSK,STZ,O,ARES,EL,URI,PAYX,DLR,KMB,D,BK,A,AMP,COR,KHC,LEN,ALL,FIS,PRU,IDXX,CCI,LHX,KMI,HUM,IQV,PWR,DDOG,SE
# ...

# %%
tickers.download(period='1d', interval='1m')
# Out:
# [******                13%                       ]  589 of 4460 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tickers.download(period='1d', interval='1m')
#
# File d:\code\Python\Python38\lib\site-packages\yfinance\tickers.py:65, in Tickers.download(self, period, interval, start, end, prepost, actions, auto_adjust, repair, proxy, threads, group_by, progress, timeout, **kwargs)
#      58 def download(self, period="1mo", interval="1d",
#      59              start=None, end=None, prepost=False,
#      60              actions=True, auto_adjust=True, repair=False,
#      61              proxy=None,
#      62              threads=True, group_by='column', progress=True,
#      63              timeout=10, **kwargs):
# ---> 65     data = multi.download(self.symbols,
#      66                           start=start, end=end,
# ...
