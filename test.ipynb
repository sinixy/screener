# %%
import pandas as pd
from tradingview_screener import Scanner, Query, Column
# Out:
# d:\soft\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
(Query()
 .select('close', 'volume', 'market_cap_basic', 'pre_change|5')
 .where(
     Column('type') == 'stock',
     Column('is_primary') == True
 )
 .order_by('pre_change|5', ascending=False)
 .get_scanner_data()
)
# Out:
# {'markets': ['america'], 'symbols': {'query': {'types': []}, 'tickers': []}, 'options': {'lang': 'en'}, 'columns': ['close', 'volume', 'market_cap_basic', 'pre_change|5'], 'sort': {'sortBy': 'pre_change|5', 'sortOrder': 'desc'}, 'range': [0, 50], 'filter': [{'left': 'type', 'operation': 'equal', 'right': 'stock'}, {'left': 'is_primary', 'operation': 'equal', 'right': True}]}
# (7245,
#            ticker         close    volume  market_cap_basic pre_change|5
#  0      OTC:ZHYBF      5.240000       100      9.264119e+07         None
#  1       NYSE:FTV     74.560000   1423315      2.624726e+10         None
#  2       OTC:FINN  12100.000000         2      3.678400e+09         None
#  3      NYSE:MAIN     48.220000    293475      4.133207e+09         None
#  4       OTC:CITZ     31.000000       775               NaN         None
#  5      NYSE:RBOT      0.331000    465802      5.826753e+07         None
#  6      NYSE:GRMN    162.400000    704866      3.119342e+10         None
# ...
